# %%
# Import modules for: regular expressions; reading timestamps as date objects; loading files using regular expression;
# generate random numbers; reading JSONL files; working with XML files
import re
from datetime import datetime
from glob import glob
import jsonlines
import pandas as pd
import operator
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

# %%
# List all filenames with the .jsonl extension
files = glob("*.jsonl")

# For each file do:
for file in files:
    # create an empty list to save the spreadsheet rows
    data = []
    output_filename = file.replace("*.jsonl", "") + ".csv"
    # Read the file as a jsonlines one:
    with jsonlines.open(file) as comments:
        # For each line (i.e. metadata data-points for one comment) do:
        for comment in comments:
            # Extract the comment id ('cid') and save it to a variable
            comment_id = str(comment["cid"])
            print(f"Processing comment {comment_id}")
            # Check if the 'cid' contains a full stop character. If so, the comment is a reply to another comment: take the string on
            # the left of the full stop and assign it as value of the attribute 'comment_id', then the string on the right and assign
            # it as value of the attribute 'comment_reply_to' to preserve the original hierarchical structure
            if re.search("(.*?)\.(.*)", comment_id) is not None:
                comment_reply_to = str(
                    re.search("(.*?)\.(.*)", comment_id).group(1)
                )
                comment_id = str(
                    re.search("(.*?)\.(.*)", comment_id).group(2)
                )
            # If there is no full stop character, assign the 'comment_id' as value of the <comment> attribute 'comment_id' and the
            # value 'na' to the 'comment_reply_to' attribute
            else:
                comment_id = comment_id
                comment_reply_to = "na"

            # Extract other metadata data-points and assign them to a set of variables
            username = str(comment["author"])
            votes = str(comment["votes"])
            heart = str(comment["heart"])
            comment_timestamp = comment["time_parsed"]
            
            # At last, get the content of the comment (the actual message)
            comment_text = str(comment["text"])
            
            # Calculate the sentiment of the comment, and extract the four results to four different variables
            sa_text = analyzer.polarity_scores(comment_text)
            negative = sa_text["neg"]
            neutral = sa_text["neu"]
            positive = sa_text["pos"]
            compound = sa_text["compound"]
            
            # append all the extracted data to the list, formatting it as a csv line
            data.append([comment_timestamp, comment_id, comment_reply_to, username, comment_text, negative, neutral, positive, compound])
        
        # after all the comments have been extracted, sort them in chronological order using their timestamps
        data.sort(key=operator.itemgetter(0))
        
        # add a progressive number to the newly ordered comments, to preserve the chronological order
        for index, element in enumerate(data, start=1):
            element.insert(0, index)
            
        # create a dataframe with all the collected comments
        csv_df = pd.DataFrame(data, columns=["turn", "comment_timestamp", "comment_id", "reply_to", "username", "comment_text", "negative", "neutral", "positive", "compound"])
        # write the dataframe to a csv file
        csv_df.to_csv(output_filename, sep="\t", index=False)
# Out:
# Processing comment UgxRqHRnwAelIPmIW454AaABAg
# Processing comment Ugwqe3vTioYXvaqRYLd4AaABAg
# Processing comment UgzcDSg8k5U72ykEkbJ4AaABAg
# Processing comment UgxIuIGOZfYsQRpcAtR4AaABAg
# Processing comment UgwTuFkO-Nxmb47mHaJ4AaABAg
# Processing comment UgzhDSB5zd7QKRo_EQl4AaABAg
# Processing comment UgxTFMQwfD_DdWKCo6J4AaABAg
# Processing comment Ugz6eGnTnC4Xs3UdxQp4AaABAg
# Processing comment Ugx21N5OqknyrtKlqVp4AaABAg
# Processing comment Ugy7J1_8iVVDVWDy-_N4AaABAg
# Processing comment Ugw7CQfYrcbVPKtwONd4AaABAg
# Processing comment UgyFObm3s4pfNpv7dsR4AaABAg
# Processing comment UgzA71D1uuU9zbERn9B4AaABAg
# Processing comment UgyIUNOkZ-VkSFGN-954AaABAg.9fLnPBljsTX9fMFAZILhfS
# Processing comment UgwQagQdAM2dkjpTAJ54AaABAg
# Processing comment UgxQEJcwUGH9WFDADt54AaABAg
# Processing comment UgyyHargwVQ3d5R2tt94AaABAg
# Processing comment UgzR7M7voR-XnJKIAWt4AaABAg
# Processing comment UgxrtNYsrYWHOKMY48x4AaABAg
# Processing comment UgzeMxoS2xpikW1tRJd4AaABAg
# Processing comment UgxtmMiTlzdPf6zTozV4AaABAg
# Processing comment Ugzj4-ghWFFN1rKwBO54AaABAg
# Processing comment UgyrQbt2eaYhTMWKSNR4AaABAg
# Processing comment Ugz0RVsWz25O720SdEZ4AaABAg
# Processing comment Ugx4PG0tgLpEtMp5r3x4AaABAg
# Processing comment UgxFUTYmxW0m2sQPXcV4AaABAg
# Processing comment Ugw5DSZQoZYC2HXiIed4AaABAg
# Processing comment Ugx-9GV87kAgCaaajLh4AaABAg
# Processing comment UgwAgTWJebeUVVa0XPJ4AaABAg
# Processing comment UgwI3tay441jNg8-rdd4AaABAg
# Processing comment UgypAxRL9lKGH6kNdJR4AaABAg
# Processing comment UgwQ5pqOniUyPR4j-9V4AaABAg
# Processing comment UgwHLkOLnLnpD1vE-114AaABAg
# Processing comment Ugzy3inUU2x6VZFqpHh4AaABAg
# Processing comment UgwTaktZtvhrn8Arm6t4AaABAg
# Processing comment UgwOKCtpWxfHPuV9ZMJ4AaABAg
# Processing comment UgzYctHxPot-6xcpKMN4AaABAg
# Processing comment Ugy-C6GVifG3VSPz4S94AaABAg
# Processing comment UgziV6r8sg4PbD-lIbF4AaABAg
# Processing comment UgzV0P0c_XxBF2qxmvV4AaABAg
# Processing comment UgznSxinV1mgqIeUvSN4AaABAg
# Processing comment UgzkoCaqoA1TGgiS26Z4AaABAg
# Processing comment Ugw8Vn8b6YTk1x2t4hN4AaABAg
# Processing comment UgyaDlssA5lga7lAqbF4AaABAg
# Processing comment UgyGNMP1Z-ys53LoPnx4AaABAg
# Processing comment UgyG6KIV-tr0aNychOV4AaABAg
# Processing comment Ugxw7QcFxA8J5fiuSsh4AaABAg
# Processing comment UgwCEdeaoQfNuje1Xwl4AaABAg
# Processing comment UgwUubbG8ocpFn3xrMl4AaABAg
# Processing comment UgzWhU5r-YuJ908OCNd4AaABAg
# Processing comment Ugw_wZ5PENa5Cqiv6gJ4AaABAg
# Processing comment UgxBQX6xfZqkXeQxAnF4AaABAg
# Processing comment UgyjLXR29jan-u19o3F4AaABAg
# Processing comment Ugy1POGmJ134Y5Fh_gx4AaABAg
# Processing comment UgzYctHxPot-6xcpKMN4AaABAg.9fKuNO8GOx29fOmf460rtk
# Processing comment UgzYctHxPot-6xcpKMN4AaABAg.9fKuNO8GOx29fOvkiHoea8
# Processing comment UgzYctHxPot-6xcpKMN4AaABAg.9fKuNO8GOx29fOwPJIO2VW
# Processing comment UgzYctHxPot-6xcpKMN4AaABAg.9fKuNO8GOx29fPqEedB-xO
# Processing comment UgzYctHxPot-6xcpKMN4AaABAg.9fKuNO8GOx29fRI5_0qCEA
# Processing comment UgzYctHxPot-6xcpKMN4AaABAg.9fKuNO8GOx29fvOLJS01dW
# Processing comment UgzYctHxPot-6xcpKMN4AaABAg.9fKuNO8GOx29fw4aQA0Tpi
# Processing comment UgzYctHxPot-6xcpKMN4AaABAg.9fKuNO8GOx29fwCQwI8E2U
# Processing comment UgziV6r8sg4PbD-lIbF4AaABAg.9fKt_TXynsu9fKtapKmBYa
# Processing comment UgziV6r8sg4PbD-lIbF4AaABAg.9fKt_TXynsu9fKtc1eodxb
# Processing comment UgyG6KIV-tr0aNychOV4AaABAg.9fKmMHuMmxU9fKuFUrlp2q
# Processing comment UgycOiGuoIgd9vCpCxd4AaABAg
# Processing comment UgzxnmDWqW8goHrVwCJ4AaABAg
# Processing comment UgzxrRp5-jFo1_yBmkN4AaABAg
# Processing comment UgygazjcclTbjm-veUp4AaABAg
# Processing comment Ugx1rbAUJoFn0yuYHbB4AaABAg
# Processing comment Ugwb4-MmoTRs2CpPf1d4AaABAg
# Processing comment UgxSDvnmnPD3UQGzxcF4AaABAg
# Processing comment UgxOKXDsaPVVebrke_14AaABAg
# Processing comment UgxFtRuFL4mDmSxYCPN4AaABAg
# Processing comment UgyQ2kD_5CQGH7Arbb14AaABAg
# Processing comment Ugx4U8NNe5NeKXjSHiZ4AaABAg
# Processing comment UgyfYOwBaRaT3Uj49Xt4AaABAg
# Processing comment UgxdMH8shlYklXwBOwt4AaABAg
# Processing comment Ugz5p-_0bE3SrJZd8lV4AaABAg
# Processing comment Ugw3FkbPV3kQ_O2bqtd4AaABAg
# Processing comment Ugzx751V8UkAv0cR1Wl4AaABAg
# Processing comment UgwXr-93BK5fSPG0TQB4AaABAg
# Processing comment UgxzwUv9SjI9o8n01gh4AaABAg
# Processing comment UgwiHTYdCwEPj3KcW6B4AaABAg
# Processing comment UgykIvIqVS9sqnXiJEN4AaABAg
# Processing comment UgxSDvnmnPD3UQGzxcF4AaABAg.9fKgKtROjxr9fKlNNf0P4Q
# Processing comment UgxSDvnmnPD3UQGzxcF4AaABAg.9fKgKtROjxr9fKt7f_UFjI
# Processing comment UgxSDvnmnPD3UQGzxcF4AaABAg.9fKgKtROjxr9fKtAYOkQm5
# Processing comment Ugz5p-_0bE3SrJZd8lV4AaABAg.9fKc8gQBlZR9fL44qYXgWI
# Processing comment UgykIvIqVS9sqnXiJEN4AaABAg.9fK_Wnr8zVC9fLJ4x7Er74
# Processing comment UgykIvIqVS9sqnXiJEN4AaABAg.9fK_Wnr8zVC9fLgvG6cSUP
# Processing comment UgzV4WonWzZxu_fbi254AaABAg
# Processing comment UgxjPCiFRBt1_11d7El4AaABAg
# Processing comment UgyYQC3b2_gGg_Xl52Z4AaABAg
# Processing comment UgyRGjWg-Z6Vi_gRgbd4AaABAg
# Processing comment UgxRnRytwDLoo7P5F854AaABAg
# Processing comment UgwV5hLhSlL0GgBN3Vh4AaABAg
# Processing comment Ugy_Hsf7ueANo_Y42Vx4AaABAg
# Processing comment Ugwfc5rDgIupJS-x4xh4AaABAg.9fKU6f-FVJg9fY7OUQ0nnT
# Processing comment Ugwfc5rDgIupJS-x4xh4AaABAg.9fKU6f-FVJg9fyeoUmI-Kg
# Processing comment Ugwfc5rDgIupJS-x4xh4AaABAg.9fKU6f-FVJg9g2egdtQ_cQ
# Processing comment Ugwfc5rDgIupJS-x4xh4AaABAg.9fKU6f-FVJg9gAG3IqZ607
# Processing comment UgwR3AyBP0H0ItbKBDN4AaABAg.9fKTjb0IYS09fLVaTSI1Ac
# Processing comment UgwR3AyBP0H0ItbKBDN4AaABAg.9fKTjb0IYS09fY-oswpYNW
# Processing comment UgwR3AyBP0H0ItbKBDN4AaABAg.9fKTjb0IYS09hmRK32o2P7
# Processing comment UgwE62RNYtYVUA-3AEl4AaABAg
# Processing comment UgxD509lp8rEjDM9sgV4AaABAg
# Processing comment UgzP82Nxg5RTfuNq_eZ4AaABAg
# Processing comment UgyRGnaR3qSbATCn0Ad4AaABAg
# Processing comment UgyogInV3JJHL-sWaJl4AaABAg
# Processing comment Ugwc35HJIH8rYySwpVl4AaABAg
# Processing comment UgyvAoDpbm88WnV8ip14AaABAg
# Processing comment Ugx6wQcFYd7mtwD4JfR4AaABAg
# Processing comment UgxGcugkcGIQNymRWQx4AaABAg
# Processing comment Ugy8FkRP7cvYsZHlyat4AaABAg
# Processing comment UgwSwQMjyKEyBEZzhpN4AaABAg
# Processing comment Ugx_XdCfEEmdG7KmUaJ4AaABAg
# Processing comment Ugxz5HpeDO-xyjCn4o94AaABAg
# Processing comment UgxOz6hL3wA6Lu66jwx4AaABAg
# Processing comment Ugyqgz9maLqBpdPMk6p4AaABAg
# Processing comment Ugw7-vtFjsy_0EXgFiV4AaABAg
# Processing comment Ugxob35-l0nwrcePTuB4AaABAg
# Processing comment UgyzAmrIdYmGKAM-USp4AaABAg
# Processing comment UgxcUxeP4-B8vuSDmmt4AaABAg
# Processing comment UgyFld0E7LYLIVb_sSh4AaABAg
# Processing comment UgyRGnaR3qSbATCn0Ad4AaABAg.9fKSkhmV5BE9fKu8Aqr_rv
# Processing comment UgyRGnaR3qSbATCn0Ad4AaABAg.9fKSkhmV5BE9fKyruAWaO8
# Processing comment UgyRGnaR3qSbATCn0Ad4AaABAg.9fKSkhmV5BE9fL1bMULCyI
# Processing comment UgyRGnaR3qSbATCn0Ad4AaABAg.9fKSkhmV5BE9fVU4WhynKK
# Processing comment UgyRGnaR3qSbATCn0Ad4AaABAg.9fKSkhmV5BE9fVd1vu8-Ey
# Processing comment UgyRGnaR3qSbATCn0Ad4AaABAg.9fKSkhmV5BE9fWLF0V5nrn
# Processing comment Ugx_XdCfEEmdG7KmUaJ4AaABAg.9fKS8N3GOhe9fKVfxvlSdI
# Processing comment Ugx_XdCfEEmdG7KmUaJ4AaABAg.9fKS8N3GOhe9fKW6zZQ09R
# Processing comment Ugx_XdCfEEmdG7KmUaJ4AaABAg.9fKS8N3GOhe9fKZgBL6SOn
# Processing comment Ugx_XdCfEEmdG7KmUaJ4AaABAg.9fKS8N3GOhe9fKbfq8JVWS
