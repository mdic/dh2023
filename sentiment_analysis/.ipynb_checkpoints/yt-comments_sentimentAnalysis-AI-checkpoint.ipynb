# %%
# Import modules for: regular expressions; reading timestamps as date objects; loading files using regular expression;
# generate random numbers; reading JSONL files; working with XML files
import re
from datetime import datetime
from glob import glob
import jsonlines
import pandas as pd
import operator
from transformers import pipeline
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Initialise the predefined-dictionary Sentiment Analysis tool
analyzer = SentimentIntensityAnalyzer()
# Initialise the AI Sentiment Analysis tool
sentiment_pipeline = pipeline(model="bhadresh-savani/distilbert-base-uncased-emotion")

# %%
# List all filenames with the .jsonl extension
files = glob("*.jsonl")

# For each file do:
for file in files:
    # create an empty list to save the spreadsheet rows
    data = []
    output_filename = file.replace("*.jsonl", "") + ".csv"
    # Read the file as a jsonlines one:
    with jsonlines.open(file) as comments:
        # For each line (i.e. metadata data-points for one comment) do:
        for comment in comments:
            # Extract the comment id ('cid') and save it to a variable
            comment_id = str(comment["cid"])
            print(f"Processing comment {comment_id}")
            # Check if the 'cid' contains a full stop character. If so, the comment is a reply to another comment: take the string on
            # the left of the full stop and assign it as value of the attribute 'comment_id', then the string on the right and assign
            # it as value of the attribute 'comment_reply_to' to preserve the original hierarchical structure
            if re.search("(.*?)\.(.*)", comment_id) is not None:
                comment_reply_to = str(
                    re.search("(.*?)\.(.*)", comment_id).group(1)
                )
                comment_id = str(
                    re.search("(.*?)\.(.*)", comment_id).group(2)
                )
            # If there is no full stop character, assign the 'comment_id' as value of the <comment> attribute 'comment_id' and the
            # value 'na' to the 'comment_reply_to' attribute
            else:
                comment_id = comment_id
                comment_reply_to = "na"

            # Extract other metadata data-points and assign them to a set of variables
            username = str(comment["author"])
            votes = str(comment["votes"])
            heart = str(comment["heart"])
            comment_timestamp = comment["time_parsed"]
            
            # At last, get the content of the comment (the actual message)
            comment_text = str(comment["text"])
            
            #print(comment_text)
            
            # Calculate the AI sentiment of the comment, and extract the results to different variables
            ai_text = sentiment_pipeline(comment_text, top_k=None)
            for dictionary in ai_text:
                if dictionary["label"] == "fear":
                    fear = dictionary["score"]
                elif dictionary["label"] == "joy":
                    joy = dictionary["score"]
                elif dictionary["label"] == "anger":
                    anger = dictionary["score"]
                elif dictionary["label"] == "sadness":
                    sadness = dictionary["score"]
                elif dictionary["label"] == "love":
                    love = dictionary["score"]
                elif dictionary["label"] == "surprise":
                    surprise = dictionary["score"]

                    # Calculate the predefined-dictionary sentiment of the comment, and extract the four results to four different variables
            pred_text = analyzer.polarity_scores(comment_text)
            negative = pred_text["neg"]
            neutral = pred_text["neu"]
            positive = pred_text["pos"]
            compound = pred_text["compound"]
            
            # append all the extracted data to the list, formatting it as a csv line
            data.append([comment_timestamp, comment_id, comment_reply_to, username, comment_text, negative, neutral, positive, compound, fear, joy, anger, sadness, love, surprise])
            
        # after all the comments have been extracted, sort them in chronological order using their timestamps
        data.sort(key=operator.itemgetter(0))
        
        # add a progressive number to the newly ordered comments, to preserve the chronological order
        for index, element in enumerate(data, start=1):
            element.insert(0, index)
            
        # create a dataframe with all the collected comments
        csv_df = pd.DataFrame(data, columns=["turn", "comment_timestamp", "comment_id", "reply_to", "username", "comment_text", "negative", "neutral", "positive", "compound", "fear", "joy", "anger", "sadness", "love", "surprise"])
        # write the dataframe to a csv file
        csv_df.to_csv(output_filename, sep="\t", index=False)
# Out:
# Processing comment UgxRqHRnwAelIPmIW454AaABAg
# [{'label': 'joy', 'score': 0.9969204664230347}, {'label': 'anger', 'score': 0.0010109911672770977}, {'label': 'sadness', 'score': 0.000612446223385632}, {'label': 'fear', 'score': 0.0006110440008342266}, {'label': 'love', 'score': 0.0005889174644835293}, {'label': 'surprise', 'score': 0.0002562185109127313}]
# Processing comment Ugwqe3vTioYXvaqRYLd4AaABAg
# [{'label': 'joy', 'score': 0.9816443920135498}, {'label': 'anger', 'score': 0.008725502528250217}, {'label': 'fear', 'score': 0.004825378302484751}, {'label': 'sadness', 'score': 0.003243070561438799}, {'label': 'surprise', 'score': 0.0008458417723886669}, {'label': 'love', 'score': 0.0007158176158554852}]
# Processing comment UgzcDSg8k5U72ykEkbJ4AaABAg
# [{'label': 'joy', 'score': 0.9424716830253601}, {'label': 'anger', 'score': 0.03320019692182541}, {'label': 'surprise', 'score': 0.014175686053931713}, {'label': 'sadness', 'score': 0.004915421828627586}, {'label': 'fear', 'score': 0.0034292603377252817}, {'label': 'love', 'score': 0.0018077429849654436}]
# Processing comment UgxIuIGOZfYsQRpcAtR4AaABAg
# [{'label': 'fear', 'score': 0.6614846587181091}, {'label': 'joy', 'score': 0.20756202936172485}, {'label': 'anger', 'score': 0.09160801023244858}, {'label': 'sadness', 'score': 0.026845412328839302}, {'label': 'surprise', 'score': 0.008465771563351154}, {'label': 'love', 'score': 0.00403409730643034}]
# Processing comment UgwTuFkO-Nxmb47mHaJ4AaABAg
# [{'label': 'fear', 'score': 0.9628428816795349}, {'label': 'anger', 'score': 0.013064300641417503}, {'label': 'sadness', 'score': 0.01112283207476139}, {'label': 'joy', 'score': 0.0076154060661792755}, {'label': 'surprise', 'score': 0.0046712723560631275}, {'label': 'love', 'score': 0.0006832903018221259}]
# Processing comment UgzhDSB5zd7QKRo_EQl4AaABAg
# [{'label': 'joy', 'score': 0.9563873410224915}, {'label': 'anger', 'score': 0.02713589183986187}, {'label': 'fear', 'score': 0.008490241132676601}, {'label': 'sadness', 'score': 0.003989188466221094}, {'label': 'surprise', 'score': 0.0021966195199638605}, {'label': 'love', 'score': 0.0018007347825914621}]
# Processing comment UgxTFMQwfD_DdWKCo6J4AaABAg
# [{'label': 'joy', 'score': 0.996567964553833}, {'label': 'love', 'score': 0.0010785282356664538}, {'label': 'sadness', 'score': 0.0007882065256126225}, {'label': 'anger', 'score': 0.0006427720654755831}, {'label': 'surprise', 'score': 0.0004769715596921742}, {'label': 'fear', 'score': 0.0004453239671420306}]
# Processing comment Ugz6eGnTnC4Xs3UdxQp4AaABAg
# [{'label': 'joy', 'score': 0.7664517760276794}, {'label': 'anger', 'score': 0.173614501953125}, {'label': 'fear', 'score': 0.025498438626527786}, {'label': 'sadness', 'score': 0.017849545925855637}, {'label': 'love', 'score': 0.010616810992360115}, {'label': 'surprise', 'score': 0.005968867801129818}]
# Processing comment Ugx21N5OqknyrtKlqVp4AaABAg
# [{'label': 'anger', 'score': 0.8854965567588806}, {'label': 'joy', 'score': 0.04156392812728882}, {'label': 'fear', 'score': 0.03653882443904877}, {'label': 'sadness', 'score': 0.03261604905128479}, {'label': 'love', 'score': 0.0018988532247021794}, {'label': 'surprise', 'score': 0.0018858397379517555}]
# Processing comment Ugy7J1_8iVVDVWDy-_N4AaABAg
# [{'label': 'joy', 'score': 0.6190770268440247}, {'label': 'sadness', 'score': 0.26033028960227966}, {'label': 'anger', 'score': 0.08484859019517899}, {'label': 'fear', 'score': 0.028008803725242615}, {'label': 'surprise', 'score': 0.004472263157367706}, {'label': 'love', 'score': 0.0032630187924951315}]
# Processing comment Ugw7CQfYrcbVPKtwONd4AaABAg
# [{'label': 'joy', 'score': 0.7941246032714844}, {'label': 'anger', 'score': 0.12151017040014267}, {'label': 'fear', 'score': 0.05667342245578766}, {'label': 'sadness', 'score': 0.02096603624522686}, {'label': 'love', 'score': 0.00475772749632597}, {'label': 'surprise', 'score': 0.00196816585958004}]
# Processing comment UgyKkYmCTCHjxJb2Dip4AaABAg
# [{'label': 'joy', 'score': 0.9731640815734863}, {'label': 'anger', 'score': 0.01820923388004303}, {'label': 'sadness', 'score': 0.0027526968624442816}, {'label': 'fear', 'score': 0.002620750805363059}, {'label': 'surprise', 'score': 0.0019958859775215387}, {'label': 'love', 'score': 0.0012574619613587856}]
# Processing comment UgyYj3uruk7av8cpPMl4AaABAg
# [{'label': 'anger', 'score': 0.9975559711456299}, {'label': 'sadness', 'score': 0.0008665039204061031}, {'label': 'joy', 'score': 0.000516817148309201}, {'label': 'fear', 'score': 0.00048169580986723304}, {'label': 'love', 'score': 0.00037683339905925095}, {'label': 'surprise', 'score': 0.0002021032414631918}]
# Processing comment UgwTM7W1A_KZ5lE5UNB4AaABAg
# [{'label': 'joy', 'score': 0.5594506859779358}, {'label': 'anger', 'score': 0.41458162665367126}, {'label': 'fear', 'score': 0.010582669638097286}, {'label': 'love', 'score': 0.006880559492856264}, {'label': 'sadness', 'score': 0.00582429114729166}, {'label': 'surprise', 'score': 0.0026801780331879854}]
# Processing comment UgxYMZCFRGykyzF1GJt4AaABAg
# [{'label': 'joy', 'score': 0.8597100377082825}, {'label': 'anger', 'score': 0.08644036203622818}, {'label': 'fear', 'score': 0.04108056798577309}, {'label': 'sadness', 'score': 0.00863378494977951}, {'label': 'love', 'score': 0.0023000056389719248}, {'label': 'surprise', 'score': 0.0018352839397266507}]
# Processing comment Ugx6FF3iZjsf2I9fba94AaABAg
# [{'label': 'anger', 'score': 0.6165849566459656}, {'label': 'joy', 'score': 0.1879064291715622}, {'label': 'fear', 'score': 0.1346588432788849}, {'label': 'sadness', 'score': 0.04158730059862137}, {'label': 'surprise', 'score': 0.011202950961887836}, {'label': 'love', 'score': 0.008059537038207054}]
# Processing comment UgwpV54NKStSfz4C8DV4AaABAg
# [{'label': 'joy', 'score': 0.7326521277427673}, {'label': 'anger', 'score': 0.218092143535614}, {'label': 'sadness', 'score': 0.026315325871109962}, {'label': 'fear', 'score': 0.016456715762615204}, {'label': 'love', 'score': 0.003598099807277322}, {'label': 'surprise', 'score': 0.002885592868551612}]
# Processing comment UgzGwtc35zsJu9YmOFV4AaABAg
# [{'label': 'anger', 'score': 0.9668650031089783}, {'label': 'fear', 'score': 0.02259005606174469}, {'label': 'sadness', 'score': 0.006145462393760681}, {'label': 'joy', 'score': 0.003230932168662548}, {'label': 'surprise', 'score': 0.0006575477309525013}, {'label': 'love', 'score': 0.0005110368365421891}]
# Processing comment UgzMp-F9XRzAO19M3I14AaABAg
# [{'label': 'anger', 'score': 0.4054216146469116}, {'label': 'fear', 'score': 0.20170214772224426}, {'label': 'joy', 'score': 0.18483927845954895}, {'label': 'sadness', 'score': 0.17957453429698944}, {'label': 'surprise', 'score': 0.014394465833902359}, {'label': 'love', 'score': 0.014068053103983402}]
# Processing comment UgznIlEE37xTnzLvj9d4AaABAg
# [{'label': 'anger', 'score': 0.34201934933662415}, {'label': 'joy', 'score': 0.2722741365432739}, {'label': 'sadness', 'score': 0.2211710512638092}, {'label': 'fear', 'score': 0.15600191056728363}, {'label': 'surprise', 'score': 0.005652023479342461}, {'label': 'love', 'score': 0.0028815146069973707}]
# Processing comment UgxRqHRnwAelIPmIW454AaABAg.9fKRB1bGumM9fKRKgv7134
# [{'label': 'joy', 'score': 0.9803613424301147}, {'label': 'anger', 'score': 0.00656567607074976}, {'label': 'sadness', 'score': 0.0054265474900603294}, {'label': 'fear', 'score': 0.0034151985310018063}, {'label': 'surprise', 'score': 0.0024387117009609938}, {'label': 'love', 'score': 0.0017925718566402793}]
# Processing comment UgxRqHRnwAelIPmIW454AaABAg.9fKRB1bGumM9fKUPjdobqc
# [{'label': 'anger', 'score': 0.4900687634944916}, {'label': 'fear', 'score': 0.27577072381973267}, {'label': 'joy', 'score': 0.20936092734336853}, {'label': 'sadness', 'score': 0.012657009065151215}, {'label': 'surprise', 'score': 0.008715840987861156}, {'label': 'love', 'score': 0.0034268409945070744}]
# Processing comment UgxRqHRnwAelIPmIW454AaABAg.9fKRB1bGumM9fL7Hua4NNL
# [{'label': 'joy', 'score': 0.6385249495506287}, {'label': 'anger', 'score': 0.2447483241558075}, {'label': 'fear', 'score': 0.08716005086898804}, {'label': 'sadness', 'score': 0.02121032401919365}, {'label': 'surprise', 'score': 0.006013688165694475}, {'label': 'love', 'score': 0.0023427195847034454}]
# Processing comment UgxRqHRnwAelIPmIW454AaABAg.9fKRB1bGumM9fLEs-Le90R
# [{'label': 'joy', 'score': 0.7247446775436401}, {'label': 'anger', 'score': 0.227118119597435}, {'label': 'sadness', 'score': 0.024716263636946678}, {'label': 'fear', 'score': 0.017065878957509995}, {'label': 'love', 'score': 0.0035887998528778553}, {'label': 'surprise', 'score': 0.0027662075590342283}]
# Processing comment UgxRqHRnwAelIPmIW454AaABAg.9fKRB1bGumM9fLJtSRT1ZA
# [{'label': 'joy', 'score': 0.906304657459259}, {'label': 'anger', 'score': 0.06093404069542885}, {'label': 'sadness', 'score': 0.020807772874832153}, {'label': 'fear', 'score': 0.008689436130225658}, {'label': 'love', 'score': 0.0022404559422284365}, {'label': 'surprise', 'score': 0.0010236852103844285}]
# Processing comment Ugxt173GTEqbhUKPw6t4AaABAg
# [{'label': 'anger', 'score': 0.5985111594200134}, {'label': 'fear', 'score': 0.22591938078403473}, {'label': 'joy', 'score': 0.1448289304971695}, {'label': 'sadness', 'score': 0.018859446048736572}, {'label': 'love', 'score': 0.0067244297824800014}, {'label': 'surprise', 'score': 0.005156694445759058}]
# Processing comment UgyY2z6w4qMyjD0L2UJ4AaABAg
# [{'label': 'anger', 'score': 0.9940524697303772}, {'label': 'sadness', 'score': 0.0031397552229464054}, {'label': 'fear', 'score': 0.0018565596546977758}, {'label': 'joy', 'score': 0.0004716640105471015}, {'label': 'love', 'score': 0.0003141878987662494}, {'label': 'surprise', 'score': 0.00016542617231607437}]
# Processing comment Ugyn2xTns3h-YiHkbI14AaABAg
# [{'label': 'anger', 'score': 0.8633081316947937}, {'label': 'joy', 'score': 0.11156979203224182}, {'label': 'fear', 'score': 0.012996970675885677}, {'label': 'sadness', 'score': 0.00794964749366045}, {'label': 'surprise', 'score': 0.0027670853305608034}, {'label': 'love', 'score': 0.0014084021095186472}]
# Processing comment Ugyjs1oCm78XzTTYKHh4AaABAg
# [{'label': 'fear', 'score': 0.5041854977607727}, {'label': 'anger', 'score': 0.369411826133728}, {'label': 'joy', 'score': 0.07754358649253845}, {'label': 'sadness', 'score': 0.03415314108133316}, {'label': 'surprise', 'score': 0.008583258837461472}, {'label': 'love', 'score': 0.0061226412653923035}]
# Processing comment Ugy6DT9mTmTUZnTduRl4AaABAg
# [{'label': 'anger', 'score': 0.9604901671409607}, {'label': 'joy', 'score': 0.028827745467424393}, {'label': 'fear', 'score': 0.0064410315826535225}, {'label': 'sadness', 'score': 0.002481803996488452}, {'label': 'love', 'score': 0.0009914713446050882}, {'label': 'surprise', 'score': 0.0007676749373786151}]
# Processing comment UgwZOo9rBb0OhEI4mLx4AaABAg
# [{'label': 'joy', 'score': 0.9258944392204285}, {'label': 'anger', 'score': 0.04077596217393875}, {'label': 'fear', 'score': 0.01627933233976364}, {'label': 'sadness', 'score': 0.012381886132061481}, {'label': 'love', 'score': 0.0027952028904110193}, {'label': 'surprise', 'score': 0.001873141503892839}]
# Processing comment UgwBSvdI405Q4HDvBy54AaABAg
# [{'label': 'anger', 'score': 0.9955686926841736}, {'label': 'joy', 'score': 0.0016038933536037803}, {'label': 'sadness', 'score': 0.0014698373852297664}, {'label': 'fear', 'score': 0.0006264095427468419}, {'label': 'love', 'score': 0.0004871280398219824}, {'label': 'surprise', 'score': 0.0002440019161440432}]
# Processing comment UgwN6ibtRlWm-Q5qvEN4AaABAg
# [{'label': 'anger', 'score': 0.43467262387275696}, {'label': 'fear', 'score': 0.37893906235694885}, {'label': 'joy', 'score': 0.15251480042934418}, {'label': 'sadness', 'score': 0.020757488906383514}, {'label': 'surprise', 'score': 0.008983918465673923}, {'label': 'love', 'score': 0.0041320426389575005}]
# Processing comment Ugyx1nolMDg59qvNjqh4AaABAg
# [{'label': 'joy', 'score': 0.8822591304779053}, {'label': 'anger', 'score': 0.09275060147047043}, {'label': 'sadness', 'score': 0.009845718741416931}, {'label': 'fear', 'score': 0.007135776802897453}, {'label': 'love', 'score': 0.0059312451630830765}, {'label': 'surprise', 'score': 0.002077486366033554}]
# Processing comment Ugx1GhKTbRnzrIy3OKN4AaABAg
# [{'label': 'anger', 'score': 0.8768897652626038}, {'label': 'joy', 'score': 0.048581313341856}, {'label': 'fear', 'score': 0.04471341893076897}, {'label': 'sadness', 'score': 0.02266956865787506}, {'label': 'love', 'score': 0.004254940897226334}, {'label': 'surprise', 'score': 0.0028909870889037848}]
# Processing comment UgzqxJo3ZFBQ2IilkaB4AaABAg
# [{'label': 'anger', 'score': 0.47132477164268494}, {'label': 'fear', 'score': 0.24516069889068604}, {'label': 'joy', 'score': 0.2186375856399536}, {'label': 'sadness', 'score': 0.04801430180668831}, {'label': 'love', 'score': 0.010206826031208038}, {'label': 'surprise', 'score': 0.006655878387391567}]
# Processing comment UgyBrq7VDdzrigIKD-94AaABAg
# [{'label': 'joy', 'score': 0.9950008988380432}, {'label': 'anger', 'score': 0.0015902298036962748}, {'label': 'sadness', 'score': 0.0014105882728472352}, {'label': 'love', 'score': 0.0008918240782804787}, {'label': 'surprise', 'score': 0.0006986868684180081}, {'label': 'fear', 'score': 0.00040775074739940464}]
# Processing comment UgxQ7YGKn07ZVdH2Mv14AaABAg
# [{'label': 'joy', 'score': 0.8933250308036804}, {'label': 'anger', 'score': 0.07114958018064499}, {'label': 'sadness', 'score': 0.02380165085196495}, {'label': 'fear', 'score': 0.0072035719640553}, {'label': 'love', 'score': 0.003212178125977516}, {'label': 'surprise', 'score': 0.001308026839978993}]
# Processing comment UgwYRNf2N2orOzVTjgZ4AaABAg
# [{'label': 'sadness', 'score': 0.9976074695587158}, {'label': 'anger', 'score': 0.0008056008955463767}, {'label': 'fear', 'score': 0.0006410259520635009}, {'label': 'joy', 'score': 0.000631132919806987}, {'label': 'surprise', 'score': 0.00017433342873118818}, {'label': 'love', 'score': 0.00014047094737179577}]
# Processing comment UgxtZQyU_gFdzqhD7yV4AaABAg
# [{'label': 'anger', 'score': 0.8945401310920715}, {'label': 'fear', 'score': 0.07898172736167908}, {'label': 'sadness', 'score': 0.020265014842152596}, {'label': 'joy', 'score': 0.004877404309809208}, {'label': 'surprise', 'score': 0.0007815837161615491}, {'label': 'love', 'score': 0.0005541978753171861}]
# Processing comment UgyTNXjGH0uoUQG-ojd4AaABAg
# [{'label': 'anger', 'score': 0.798788845539093}, {'label': 'joy', 'score': 0.14278051257133484}, {'label': 'fear', 'score': 0.03679951652884483}, {'label': 'sadness', 'score': 0.013926872052252293}, {'label': 'surprise', 'score': 0.004664835520088673}, {'label': 'love', 'score': 0.003039400326088071}]
# Processing comment UgylFMc7g_sQbREM3Hx4AaABAg
# [{'label': 'joy', 'score': 0.9897794127464294}, {'label': 'anger', 'score': 0.004278860986232758}, {'label': 'fear', 'score': 0.0023222211748361588}, {'label': 'sadness', 'score': 0.0017697749426588416}, {'label': 'love', 'score': 0.0013339852448552847}, {'label': 'surprise', 'score': 0.0005159006104804575}]
# Processing comment UgxX_S95-4M1V-uda9J4AaABAg
# [{'label': 'anger', 'score': 0.5919895768165588}, {'label': 'fear', 'score': 0.3961099088191986}, {'label': 'joy', 'score': 0.005666344426572323}, {'label': 'love', 'score': 0.002635906683281064}, {'label': 'surprise', 'score': 0.0019386779749765992}, {'label': 'sadness', 'score': 0.0016595766646787524}]
# Processing comment Ugx7P-Mku_nmkU4oMGN4AaABAg
# [{'label': 'joy', 'score': 0.8714898228645325}, {'label': 'anger', 'score': 0.09639621526002884}, {'label': 'fear', 'score': 0.019536824896931648}, {'label': 'sadness', 'score': 0.008658522740006447}, {'label': 'love', 'score': 0.002387329936027527}, {'label': 'surprise', 'score': 0.0015313101466745138}]
# Processing comment UgyGyj6_G_KxJQSeZHl4AaABAg
# [{'label': 'joy', 'score': 0.9629908800125122}, {'label': 'surprise', 'score': 0.030555130913853645}, {'label': 'sadness', 'score': 0.0020977151580154896}, {'label': 'anger', 'score': 0.001906778197735548}, {'label': 'fear', 'score': 0.0014454914489760995}, {'label': 'love', 'score': 0.0010039370972663164}]
# Processing comment UgyY2z6w4qMyjD0L2UJ4AaABAg.9fX64JdFfwD9fXCeo830th
# [{'label': 'anger', 'score': 0.4054216146469116}, {'label': 'fear', 'score': 0.20170214772224426}, {'label': 'joy', 'score': 0.18483927845954895}, {'label': 'sadness', 'score': 0.17957453429698944}, {'label': 'surprise', 'score': 0.014394465833902359}, {'label': 'love', 'score': 0.014068053103983402}]
# Processing comment Ugy13U0miKHgrzgQMOF4AaABAg
# [{'label': 'anger', 'score': 0.5641916394233704}, {'label': 'joy', 'score': 0.2253081500530243}, {'label': 'fear', 'score': 0.18574519455432892}, {'label': 'sadness', 'score': 0.011855664663016796}, {'label': 'surprise', 'score': 0.00657705357298255}, {'label': 'love', 'score': 0.006322337780147791}]
# Processing comment UgxAJStfetFwrP6_fnR4AaABAg
# [{'label': 'anger', 'score': 0.9581137895584106}, {'label': 'sadness', 'score': 0.016152681782841682}, {'label': 'fear', 'score': 0.013765878044068813}, {'label': 'joy', 'score': 0.01005130261182785}, {'label': 'love', 'score': 0.0010862748604267836}, {'label': 'surprise', 'score': 0.0008300881600007415}]
# Processing comment UgxyJZLY8o9oVPTdK-x4AaABAg
# [{'label': 'anger', 'score': 0.5736007690429688}, {'label': 'joy', 'score': 0.3466644585132599}, {'label': 'fear', 'score': 0.03661002591252327}, {'label': 'sadness', 'score': 0.02274906076490879}, {'label': 'surprise', 'score': 0.011408484540879726}, {'label': 'love', 'score': 0.00896724034100771}]
# Processing comment UgwTVXUQL5PJPsgBfqJ4AaABAg
# [{'label': 'joy', 'score': 0.9426911473274231}, {'label': 'anger', 'score': 0.02304224856197834}, {'label': 'fear', 'score': 0.018100135028362274}, {'label': 'sadness', 'score': 0.011755186133086681}, {'label': 'surprise', 'score': 0.0025038679596036673}, {'label': 'love', 'score': 0.0019074883311986923}]
# Processing comment UgzrYMLTRmIfth4KHQ54AaABAg
# [{'label': 'joy', 'score': 0.9970182180404663}, {'label': 'anger', 'score': 0.0008465001010335982}, {'label': 'fear', 'score': 0.0007802139734849334}, {'label': 'sadness', 'score': 0.0005541977006942034}, {'label': 'surprise', 'score': 0.0004859163600485772}, {'label': 'love', 'score': 0.0003151183482259512}]
# Processing comment Ugza421QN3GNp50BRvh4AaABAg
# [{'label': 'joy', 'score': 0.5406818985939026}, {'label': 'anger', 'score': 0.35302409529685974}, {'label': 'sadness', 'score': 0.0541933998465538}, {'label': 'fear', 'score': 0.041824471205472946}, {'label': 'love', 'score': 0.006156012415885925}, {'label': 'surprise', 'score': 0.00412012031301856}]
# Processing comment Ugzh2PEKYVbHiehS0UJ4AaABAg
# [{'label': 'joy', 'score': 0.995895266532898}, {'label': 'love', 'score': 0.001170612871646881}, {'label': 'sadness', 'score': 0.0011513683712109923}, {'label': 'anger', 'score': 0.0010435214499011636}, {'label': 'surprise', 'score': 0.00046601431677117944}, {'label': 'fear', 'score': 0.0002733353467192501}]
# Processing comment UgwbphMCu420Eai35FN4AaABAg
# [{'label': 'love', 'score': 0.9903218150138855}, {'label': 'sadness', 'score': 0.0030014554504305124}, {'label': 'anger', 'score': 0.0027675065211951733}, {'label': 'joy', 'score': 0.002533572493121028}, {'label': 'surprise', 'score': 0.0007631314219906926}, {'label': 'fear', 'score': 0.0006126216612756252}]
# Processing comment Ugxzqd7W3j-rCp_1fdx4AaABAg
# [{'label': 'joy', 'score': 0.8298526406288147}, {'label': 'anger', 'score': 0.11163626611232758}, {'label': 'fear', 'score': 0.03319687396287918}, {'label': 'sadness', 'score': 0.0187070369720459}, {'label': 'surprise', 'score': 0.0035208293702453375}, {'label': 'love', 'score': 0.0030863843858242035}]
# Processing comment UgzV8oFNDCZoR60mObR4AaABAg
# [{'label': 'fear', 'score': 0.6483789086341858}, {'label': 'anger', 'score': 0.15386225283145905}, {'label': 'joy', 'score': 0.11964831501245499}, {'label': 'sadness', 'score': 0.04691426828503609}, {'label': 'surprise', 'score': 0.02918311581015587}, {'label': 'love', 'score': 0.002013174816966057}]
# Processing comment UgyRchFZGWwxzbUYBZl4AaABAg
# [{'label': 'joy', 'score': 0.9905796647071838}, {'label': 'anger', 'score': 0.005286795552819967}, {'label': 'sadness', 'score': 0.001501041348092258}, {'label': 'fear', 'score': 0.0011824091197922826}, {'label': 'love', 'score': 0.0009982227347791195}, {'label': 'surprise', 'score': 0.0004518584755714983}]
# Processing comment UgxAdveHkdcr8clyqm94AaABAg
# [{'label': 'joy', 'score': 0.8884785175323486}, {'label': 'anger', 'score': 0.08930907398462296}, {'label': 'fear', 'score': 0.009215430356562138}, {'label': 'sadness', 'score': 0.008458062075078487}, {'label': 'love', 'score': 0.0027100290171802044}, {'label': 'surprise', 'score': 0.0018289375584572554}]
# Processing comment Ugwc0ns6VTV-Qe6OGax4AaABAg
# [{'label': 'anger', 'score': 0.7504502534866333}, {'label': 'joy', 'score': 0.114168182015419}, {'label': 'fear', 'score': 0.0783541277050972}, {'label': 'sadness', 'score': 0.05171234533190727}, {'label': 'surprise', 'score': 0.002841140143573284}, {'label': 'love', 'score': 0.00247391895391047}]
# Processing comment UgyCsPLVSjuS-7ipBJZ4AaABAg
# [{'label': 'joy', 'score': 0.9555696845054626}, {'label': 'anger', 'score': 0.02716119959950447}, {'label': 'fear', 'score': 0.007794592529535294}, {'label': 'sadness', 'score': 0.005002249963581562}, {'label': 'surprise', 'score': 0.0034095109440386295}, {'label': 'love', 'score': 0.0010627316078171134}]
# Processing comment UgxlW9r2J3RjG8RdQoN4AaABAg
# [{'label': 'surprise', 'score': 0.642488956451416}, {'label': 'joy', 'score': 0.30911049246788025}, {'label': 'fear', 'score': 0.026374461129307747}, {'label': 'anger', 'score': 0.012035638093948364}, {'label': 'sadness', 'score': 0.007151497527956963}, {'label': 'love', 'score': 0.00283901859074831}]
# Processing comment UgyCJ_w5FebqXX2prSx4AaABAg
# [{'label': 'sadness', 'score': 0.9955524802207947}, {'label': 'joy', 'score': 0.001497599296271801}, {'label': 'fear', 'score': 0.001420829794369638}, {'label': 'anger', 'score': 0.0009413676452822983}, {'label': 'surprise', 'score': 0.00034165504621341825}, {'label': 'love', 'score': 0.00024597730953246355}]
# Processing comment Ugzhc5XFc-ZJJb9BP2p4AaABAg
# [{'label': 'joy', 'score': 0.9956223368644714}, {'label': 'anger', 'score': 0.0014928188174962997}, {'label': 'surprise', 'score': 0.0009523425833322108}, {'label': 'sadness', 'score': 0.0007326671038754284}, {'label': 'fear', 'score': 0.0007164987619034946}, {'label': 'love', 'score': 0.00048334343591704965}]
# Processing comment UgxpPJTaPH7MOe6KfoV4AaABAg
# [{'label': 'anger', 'score': 0.9871125817298889}, {'label': 'sadness', 'score': 0.007704535964876413}, {'label': 'joy', 'score': 0.0033033413346856833}, {'label': 'fear', 'score': 0.0012567979283630848}, {'label': 'love', 'score': 0.0003370402555447072}, {'label': 'surprise', 'score': 0.0002857514191418886}]
# Processing comment Ugwfr_GvjHDpzCiG9WJ4AaABAg
# [{'label': 'anger', 'score': 0.617407500743866}, {'label': 'joy', 'score': 0.26832929253578186}, {'label': 'fear', 'score': 0.07881804555654526}, {'label': 'sadness', 'score': 0.02670220099389553}, {'label': 'surprise', 'score': 0.005498588550835848}, {'label': 'love', 'score': 0.003244433319196105}]
# Processing comment UgwTYMQ2-PE1HQSjxjV4AaABAg
# [{'label': 'joy', 'score': 0.9573768973350525}, {'label': 'anger', 'score': 0.025408998131752014}, {'label': 'sadness', 'score': 0.007205349858850241}, {'label': 'fear', 'score': 0.005551735870540142}, {'label': 'surprise', 'score': 0.00248168408870697}, {'label': 'love', 'score': 0.001975215971469879}]
# Processing comment UgyWUFaKNbLESxTK59B4AaABAg
# [{'label': 'joy', 'score': 0.9940280914306641}, {'label': 'anger', 'score': 0.0026153407525271177}, {'label': 'fear', 'score': 0.0011322482023388147}, {'label': 'sadness', 'score': 0.0010611857287585735}, {'label': 'surprise', 'score': 0.0006297578220255673}, {'label': 'love', 'score': 0.0005333397421054542}]
# Processing comment UgwenpKO-ICOttlEa7d4AaABAg
# [{'label': 'anger', 'score': 0.5082135796546936}, {'label': 'joy', 'score': 0.4658586382865906}, {'label': 'fear', 'score': 0.012335476465523243}, {'label': 'sadness', 'score': 0.008980880491435528}, {'label': 'surprise', 'score': 0.00252068811096251}, {'label': 'love', 'score': 0.002090757479891181}]
# Processing comment UgwfnubkVEIZFgXnfyZ4AaABAg
# [{'label': 'anger', 'score': 0.9909251928329468}, {'label': 'sadness', 'score': 0.005816186312586069}, {'label': 'fear', 'score': 0.0014808448031544685}, {'label': 'joy', 'score': 0.0010711337672546506}, {'label': 'love', 'score': 0.0004236121603753418}, {'label': 'surprise', 'score': 0.00028307794127613306}]
# Processing comment UgzreEvnekytgJrZO7V4AaABAg
# [{'label': 'anger', 'score': 0.4971139430999756}, {'label': 'joy', 'score': 0.3975898325443268}, {'label': 'fear', 'score': 0.07646837830543518}, {'label': 'sadness', 'score': 0.018138952553272247}, {'label': 'surprise', 'score': 0.006928848568350077}, {'label': 'love', 'score': 0.003760078689083457}]
# Processing comment UgzT1kqt2gVqJrfHnI14AaABAg
# [{'label': 'anger', 'score': 0.7578709721565247}, {'label': 'surprise', 'score': 0.19473108649253845}, {'label': 'fear', 'score': 0.0212161373347044}, {'label': 'joy', 'score': 0.012279664166271687}, {'label': 'love', 'score': 0.008712656795978546}, {'label': 'sadness', 'score': 0.0051894234493374825}]
# Processing comment UgxvK2S80oFG_wgTyst4AaABAg
# [{'label': 'anger', 'score': 0.7913002371788025}, {'label': 'joy', 'score': 0.10266592353582382}, {'label': 'fear', 'score': 0.06684523075819016}, {'label': 'sadness', 'score': 0.02786840684711933}, {'label': 'love', 'score': 0.007252661976963282}, {'label': 'surprise', 'score': 0.004067538771778345}]
# Processing comment Ugy2gNlzqLrJ0buITMt4AaABAg
# [{'label': 'joy', 'score': 0.9003525376319885}, {'label': 'anger', 'score': 0.07409761101007462}, {'label': 'sadness', 'score': 0.015582800842821598}, {'label': 'fear', 'score': 0.004727369640022516}, {'label': 'love', 'score': 0.004364862106740475}, {'label': 'surprise', 'score': 0.0008748617838136852}]
# Processing comment Ugx1uU2eb7-UZj1ZfEN4AaABAg
# [{'label': 'joy', 'score': 0.9965646862983704}, {'label': 'anger', 'score': 0.001310432329773903}, {'label': 'surprise', 'score': 0.0006265980191528797}, {'label': 'love', 'score': 0.000625903659965843}, {'label': 'sadness', 'score': 0.0005455421633087099}, {'label': 'fear', 'score': 0.00032679643481969833}]
# Processing comment Ugy_ickP5gqAd0CaoW54AaABAg
# [{'label': 'joy', 'score': 0.9353625178337097}, {'label': 'anger', 'score': 0.05025242641568184}, {'label': 'sadness', 'score': 0.005757915321737528}, {'label': 'fear', 'score': 0.005623892415314913}, {'label': 'love', 'score': 0.001995410304516554}, {'label': 'surprise', 'score': 0.001007754122838378}]
# Processing comment UgxvBEei98MpDRGIUAp4AaABAg
# [{'label': 'fear', 'score': 0.5966598987579346}, {'label': 'sadness', 'score': 0.32159894704818726}, {'label': 'joy', 'score': 0.03342816233634949}, {'label': 'anger', 'score': 0.02823990397155285}, {'label': 'surprise', 'score': 0.017549460753798485}, {'label': 'love', 'score': 0.0025236415676772594}]
# Processing comment UgxtPIaKVx5n1pvG2ud4AaABAg
# [{'label': 'love', 'score': 0.9908664226531982}, {'label': 'joy', 'score': 0.004326432477682829}, {'label': 'sadness', 'score': 0.0031063274946063757}, {'label': 'surprise', 'score': 0.0007050368585623801}, {'label': 'anger', 'score': 0.0006343827699311078}, {'label': 'fear', 'score': 0.0003612746368162334}]
# Processing comment UgypCBmBkFEQcYDLyuR4AaABAg
# [{'label': 'joy', 'score': 0.9797494411468506}, {'label': 'anger', 'score': 0.014784431084990501}, {'label': 'sadness', 'score': 0.0016639918321743608}, {'label': 'fear', 'score': 0.0015222791116684675}, {'label': 'surprise', 'score': 0.001499017234891653}, {'label': 'love', 'score': 0.0007808214868418872}]
# Processing comment UgzA9mIbbCPyvffGzZx4AaABAg
# [{'label': 'anger', 'score': 0.9660030007362366}, {'label': 'fear', 'score': 0.02071819268167019}, {'label': 'joy', 'score': 0.00900351908057928}, {'label': 'sadness', 'score': 0.0024937111884355545}, {'label': 'surprise', 'score': 0.001194845768623054}, {'label': 'love', 'score': 0.0005867735017091036}]
# Processing comment UgyO3NrJBqs6CMZ5b-F4AaABAg
# [{'label': 'joy', 'score': 0.9849432706832886}, {'label': 'anger', 'score': 0.009497986175119877}, {'label': 'sadness', 'score': 0.002438498428091407}, {'label': 'fear', 'score': 0.0012511834502220154}, {'label': 'surprise', 'score': 0.0012322650291025639}, {'label': 'love', 'score': 0.0006368025206029415}]
# Processing comment UgyVZuWSlEh9pWqXZdh4AaABAg
# [{'label': 'anger', 'score': 0.9326362609863281}, {'label': 'fear', 'score': 0.030283376574516296}, {'label': 'sadness', 'score': 0.02102096937596798}, {'label': 'joy', 'score': 0.014012590050697327}, {'label': 'love', 'score': 0.0012511922977864742}, {'label': 'surprise', 'score': 0.0007956195622682571}]
# Processing comment UgyGOw5qpL5hGoOo6Yt4AaABAg
# [{'label': 'fear', 'score': 0.7583042979240417}, {'label': 'anger', 'score': 0.1152382642030716}, {'label': 'joy', 'score': 0.07999324053525925}, {'label': 'sadness', 'score': 0.03425746038556099}, {'label': 'surprise', 'score': 0.0074941543862223625}, {'label': 'love', 'score': 0.004712555557489395}]
# Processing comment UgwwTeZVRrh5np4i3Yt4AaABAg
# [{'label': 'joy', 'score': 0.9954481720924377}, {'label': 'surprise', 'score': 0.0014697205042466521}, {'label': 'anger', 'score': 0.001181382336653769}, {'label': 'sadness', 'score': 0.0007534325122833252}, {'label': 'fear', 'score': 0.0006718169897794724}, {'label': 'love', 'score': 0.00047562687541358173}]
# Processing comment UgyiJw7eihpALs1MXmF4AaABAg
# [{'label': 'joy', 'score': 0.9979467988014221}, {'label': 'surprise', 'score': 0.0006412289803847671}, {'label': 'anger', 'score': 0.00044490338768810034}, {'label': 'sadness', 'score': 0.00037795494426973164}, {'label': 'love', 'score': 0.00033607787918299437}, {'label': 'fear', 'score': 0.0002530618221499026}]
# Processing comment UgzPLxN_zoIl60tbey14AaABAg
# [{'label': 'joy', 'score': 0.985140323638916}, {'label': 'sadness', 'score': 0.008594824001193047}, {'label': 'anger', 'score': 0.0025780810974538326}, {'label': 'love', 'score': 0.001963783986866474}, {'label': 'surprise', 'score': 0.0012698178179562092}, {'label': 'fear', 'score': 0.00045303982915356755}]
# Processing comment UgzYUPCigdK26OEs49t4AaABAg
# [{'label': 'joy', 'score': 0.855341374874115}, {'label': 'love', 'score': 0.10879027098417282}, {'label': 'anger', 'score': 0.025828689336776733}, {'label': 'sadness', 'score': 0.005558471195399761}, {'label': 'surprise', 'score': 0.0023867215495556593}, {'label': 'fear', 'score': 0.00209457753226161}]
# Processing comment UgzA9mIbbCPyvffGzZx4AaABAg.9fMGMSKyJLs9fMQ7Vs_-Ui
# [{'label': 'joy', 'score': 0.9972525238990784}, {'label': 'surprise', 'score': 0.0006584590882994235}, {'label': 'anger', 'score': 0.0006565556395798922}, {'label': 'sadness', 'score': 0.0006448925123549998}, {'label': 'love', 'score': 0.0004115273186471313}, {'label': 'fear', 'score': 0.00037586051621474326}]
# Processing comment UgyIUNOkZ-VkSFGN-954AaABAg
# [{'label': 'anger', 'score': 0.6686384677886963}, {'label': 'joy', 'score': 0.21324028074741364}, {'label': 'fear', 'score': 0.05662805214524269}, {'label': 'sadness', 'score': 0.042224109172821045}, {'label': 'love', 'score': 0.010837382636964321}, {'label': 'surprise', 'score': 0.008431767113506794}]
# Processing comment Ugz7txVP87qT7HEJc2B4AaABAg
# [{'label': 'joy', 'score': 0.8591666221618652}, {'label': 'anger', 'score': 0.09765899181365967}, {'label': 'fear', 'score': 0.021841851994395256}, {'label': 'sadness', 'score': 0.010545879602432251}, {'label': 'surprise', 'score': 0.006458576302975416}, {'label': 'love', 'score': 0.004328153096139431}]
# Processing comment Ugx_ft8Ni04u1pnwWrd4AaABAg
# [{'label': 'joy', 'score': 0.9590476751327515}, {'label': 'love', 'score': 0.016315147280693054}, {'label': 'sadness', 'score': 0.011861216276884079}, {'label': 'anger', 'score': 0.011409192346036434}, {'label': 'surprise', 'score': 0.0008029505261220038}, {'label': 'fear', 'score': 0.0005637909634970129}]
# Processing comment UgzXd98hyGDPOqg3yP94AaABAg
# [{'label': 'joy', 'score': 0.7807375192642212}, {'label': 'anger', 'score': 0.10914448648691177}, {'label': 'fear', 'score': 0.06085922569036484}, {'label': 'sadness', 'score': 0.03860025852918625}, {'label': 'surprise', 'score': 0.005770131945610046}, {'label': 'love', 'score': 0.004888365976512432}]
# Processing comment UgyhCSTkWFuuLVnXRyB4AaABAg
# [{'label': 'joy', 'score': 0.7049397230148315}, {'label': 'anger', 'score': 0.25607097148895264}, {'label': 'fear', 'score': 0.013548840768635273}, {'label': 'sadness', 'score': 0.011667551472783089}, {'label': 'love', 'score': 0.007159767206758261}, {'label': 'surprise', 'score': 0.006613188423216343}]
# Processing comment Ugyg4cH7kgJQDqqMEBp4AaABAg
# [{'label': 'anger', 'score': 0.36062702536582947}, {'label': 'fear', 'score': 0.302153080701828}, {'label': 'joy', 'score': 0.2919672429561615}, {'label': 'sadness', 'score': 0.030614176765084267}, {'label': 'surprise', 'score': 0.009885396808385849}, {'label': 'love', 'score': 0.00475302804261446}]
# Processing comment UgzF46AUo8G77Z1RJ2t4AaABAg
# [{'label': 'joy', 'score': 0.9918739199638367}, {'label': 'love', 'score': 0.003974868915975094}, {'label': 'sadness', 'score': 0.0019979015924036503}, {'label': 'anger', 'score': 0.0016017782036215067}, {'label': 'fear', 'score': 0.00030607043299824}, {'label': 'surprise', 'score': 0.0002453462511766702}]
# Processing comment Ugygb3AkSrRPbX7r4Od4AaABAg
# [{'label': 'anger', 'score': 0.4276115596294403}, {'label': 'joy', 'score': 0.3363465368747711}, {'label': 'fear', 'score': 0.1682547777891159}, {'label': 'sadness', 'score': 0.052860792726278305}, {'label': 'love', 'score': 0.007835338823497295}, {'label': 'surprise', 'score': 0.007090934086591005}]
# Processing comment UgwfEf6EvIfgUO4VIO54AaABAg
# [{'label': 'joy', 'score': 0.9907220602035522}, {'label': 'sadness', 'score': 0.00369183998554945}, {'label': 'love', 'score': 0.002186437603086233}, {'label': 'fear', 'score': 0.001354109263047576}, {'label': 'anger', 'score': 0.0010262542637065053}, {'label': 'surprise', 'score': 0.0010194954229518771}]
# Processing comment UgzxLD4ULqGKn3RFQ094AaABAg
# [{'label': 'joy', 'score': 0.9653754830360413}, {'label': 'anger', 'score': 0.01573280058801174}, {'label': 'fear', 'score': 0.007504704874008894}, {'label': 'sadness', 'score': 0.006499644834548235}, {'label': 'love', 'score': 0.0030891054775565863}, {'label': 'surprise', 'score': 0.0017981556011363864}]
# Processing comment Ugw_iyXPnszm1gBqOuF4AaABAg
# [{'label': 'joy', 'score': 0.9216710925102234}, {'label': 'fear', 'score': 0.02634020708501339}, {'label': 'anger', 'score': 0.022881701588630676}, {'label': 'surprise', 'score': 0.02017500065267086}, {'label': 'sadness', 'score': 0.006495526060461998}, {'label': 'love', 'score': 0.002436541486531496}]
# Processing comment UgwfpgULinX3XMm-jIl4AaABAg
# [{'label': 'joy', 'score': 0.9920510649681091}, {'label': 'surprise', 'score': 0.004365494474768639}, {'label': 'anger', 'score': 0.0013160770758986473}, {'label': 'sadness', 'score': 0.0010147311259061098}, {'label': 'love', 'score': 0.000647533917799592}, {'label': 'fear', 'score': 0.0006051890668459237}]
# Processing comment UgzehXDKRqlTrQGI_xp4AaABAg
# [{'label': 'joy', 'score': 0.9913268685340881}, {'label': 'anger', 'score': 0.00487707182765007}, {'label': 'sadness', 'score': 0.0014708664966747165}, {'label': 'fear', 'score': 0.0009572447743266821}, {'label': 'love', 'score': 0.0007887932006269693}, {'label': 'surprise', 'score': 0.0005792317679151893}]
# Processing comment UgxNlFc_ISXlPbFy5Nt4AaABAg
# [{'label': 'anger', 'score': 0.6165849566459656}, {'label': 'joy', 'score': 0.1879064291715622}, {'label': 'fear', 'score': 0.1346588432788849}, {'label': 'sadness', 'score': 0.04158730059862137}, {'label': 'surprise', 'score': 0.011202950961887836}, {'label': 'love', 'score': 0.008059537038207054}]
# Processing comment UgzMR_a7A9VZVBZraqZ4AaABAg
# [{'label': 'joy', 'score': 0.9943822622299194}, {'label': 'anger', 'score': 0.002381657250225544}, {'label': 'sadness', 'score': 0.0012690535513684154}, {'label': 'fear', 'score': 0.0008006985299289227}, {'label': 'surprise', 'score': 0.0006511035608127713}, {'label': 'love', 'score': 0.000515059451572597}]
# Processing comment Ugyy34YCrM5dmo02P0d4AaABAg
# [{'label': 'anger', 'score': 0.7402015328407288}, {'label': 'fear', 'score': 0.12269792705774307}, {'label': 'joy', 'score': 0.09267470240592957}, {'label': 'sadness', 'score': 0.03419477492570877}, {'label': 'surprise', 'score': 0.005650495644658804}, {'label': 'love', 'score': 0.0045805214904248714}]
# Processing comment UgwV8uugwctWBOPlsB54AaABAg
# [{'label': 'anger', 'score': 0.8141168355941772}, {'label': 'fear', 'score': 0.12347467243671417}, {'label': 'joy', 'score': 0.050103213638067245}, {'label': 'sadness', 'score': 0.008485189639031887}, {'label': 'love', 'score': 0.0019466285593807697}, {'label': 'surprise', 'score': 0.0018734518671408296}]
# Processing comment UgwAZtAsnc2fWJKHN814AaABAg
# [{'label': 'anger', 'score': 0.44587451219558716}, {'label': 'joy', 'score': 0.27909886837005615}, {'label': 'fear', 'score': 0.21686160564422607}, {'label': 'sadness', 'score': 0.03274203836917877}, {'label': 'surprise', 'score': 0.014175716787576675}, {'label': 'love', 'score': 0.011247296817600727}]
# Processing comment UgyFObm3s4pfNpv7dsR4AaABAg
# [{'label': 'joy', 'score': 0.9976443648338318}, {'label': 'anger', 'score': 0.0006270337617024779}, {'label': 'sadness', 'score': 0.0005405915435403585}, {'label': 'love', 'score': 0.0004664838779717684}, {'label': 'surprise', 'score': 0.00040206252015195787}, {'label': 'fear', 'score': 0.00031940574990585446}]
# Processing comment UgzA71D1uuU9zbERn9B4AaABAg
# [{'label': 'joy', 'score': 0.9975134134292603}, {'label': 'love', 'score': 0.0008350555435754359}, {'label': 'sadness', 'score': 0.0006380018894560635}, {'label': 'anger', 'score': 0.0005871649482287467}, {'label': 'fear', 'score': 0.00025100092170760036}, {'label': 'surprise', 'score': 0.00017535056394990534}]
# Processing comment UgyIUNOkZ-VkSFGN-954AaABAg.9fLnPBljsTX9fMFAZILhfS
# [{'label': 'anger', 'score': 0.7841777205467224}, {'label': 'joy', 'score': 0.18388164043426514}, {'label': 'fear', 'score': 0.014115159399807453}, {'label': 'sadness', 'score': 0.011750333942472935}, {'label': 'love', 'score': 0.003175615333020687}, {'label': 'surprise', 'score': 0.0028995268512517214}]
# Processing comment UgwQagQdAM2dkjpTAJ54AaABAg
# [{'label': 'anger', 'score': 0.7776281237602234}, {'label': 'sadness', 'score': 0.16723445057868958}, {'label': 'joy', 'score': 0.03926411271095276}, {'label': 'fear', 'score': 0.009326081722974777}, {'label': 'love', 'score': 0.00555822066962719}, {'label': 'surprise', 'score': 0.0009889784269034863}]
# Processing comment UgxQEJcwUGH9WFDADt54AaABAg
# [{'label': 'sadness', 'score': 0.9050354361534119}, {'label': 'anger', 'score': 0.0547141432762146}, {'label': 'fear', 'score': 0.030581360682845116}, {'label': 'joy', 'score': 0.007715058047324419}, {'label': 'surprise', 'score': 0.0013790886150673032}, {'label': 'love', 'score': 0.0005749395349994302}]
# Processing comment UgyyHargwVQ3d5R2tt94AaABAg
# [{'label': 'joy', 'score': 0.9976237416267395}, {'label': 'surprise', 'score': 0.0007040988421067595}, {'label': 'anger', 'score': 0.0005982406437397003}, {'label': 'sadness', 'score': 0.0004657501121982932}, {'label': 'love', 'score': 0.00033884847653098404}, {'label': 'fear', 'score': 0.00026945341960527003}]
# Processing comment UgzR7M7voR-XnJKIAWt4AaABAg
# [{'label': 'joy', 'score': 0.9984713196754456}, {'label': 'sadness', 'score': 0.00046101855696178973}, {'label': 'love', 'score': 0.0003791500930674374}, {'label': 'anger', 'score': 0.00030912100919522345}, {'label': 'surprise', 'score': 0.00022425188217312098}, {'label': 'fear', 'score': 0.0001551980822114274}]
# Processing comment UgxrtNYsrYWHOKMY48x4AaABAg
# [{'label': 'joy', 'score': 0.9852655529975891}, {'label': 'anger', 'score': 0.005498160608112812}, {'label': 'fear', 'score': 0.0035574843641370535}, {'label': 'love', 'score': 0.0032624024897813797}, {'label': 'sadness', 'score': 0.0017522521084174514}, {'label': 'surprise', 'score': 0.0006640341598540545}]
# Processing comment UgzeMxoS2xpikW1tRJd4AaABAg
# [{'label': 'anger', 'score': 0.9875764846801758}, {'label': 'sadness', 'score': 0.009254305623471737}, {'label': 'joy', 'score': 0.001383615774102509}, {'label': 'fear', 'score': 0.0010222039418295026}, {'label': 'love', 'score': 0.0005348100094124675}, {'label': 'surprise', 'score': 0.00022851496760267764}]
# Processing comment UgxtmMiTlzdPf6zTozV4AaABAg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 44
#      39 comment_text = str(comment["text"])
#      41 #print(comment_text)
#      42
#      43 # Calculate the AI sentiment of the comment, and extract the results to different variables
# ---> 44 ai_text = sentiment_pipeline(comment_text, top_k=None)
#      45 print(ai_text)
#      46 #for dictionary in ai_text:
#      47 #    if dictionary["label"] == "fear":
#      48 #        print(dictionary["score"])
#    (...)
#      52         #if key["label"] == "fear":
#      53         #    print(value["score"])
#
# File ~/git_repos/dh2023/venv_sentiment-analysis/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:155, in TextClassificationPipeline.__call__(self, *args, **kwargs)
#     121 def __call__(self, *args, **kwargs):
#     122     """
#     123     Classify the text(s) given as inputs.
#     124
#    (...)
#     153         If `top_k` is used, one such dictionary is returned per label.
#     154     """
# --> 155     result = super().__call__(*args, **kwargs)
#     156     # TODO try and retrieve it in a nicer way from _sanitize_parameters.
#     157     _legacy = "top_k" not in kwargs
#
# File ~/git_repos/dh2023/venv_sentiment-analysis/lib/python3.10/site-packages/transformers/pipelines/base.py:1109, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1101     return next(
#    1102         iter(
#    1103             self.get_iterator(
#    (...)
#    1106         )
#    1107     )
#    1108 else:
# -> 1109     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/git_repos/dh2023/venv_sentiment-analysis/lib/python3.10/site-packages/transformers/pipelines/base.py:1116, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1114 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1115     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1116     model_outputs = self.forward(model_inputs, **forward_params)
#    1117     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1118     return outputs
#
# File ~/git_repos/dh2023/venv_sentiment-analysis/lib/python3.10/site-packages/transformers/pipelines/base.py:1015, in Pipeline.forward(self, model_inputs, **forward_params)
#    1013     with inference_context():
#    1014         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1015         model_outputs = self._forward(model_inputs, **forward_params)
#    1016         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1017 else:
#
# File ~/git_repos/dh2023/venv_sentiment-analysis/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:182, in TextClassificationPipeline._forward(self, model_inputs)
#     181 def _forward(self, model_inputs):
# --> 182     return self.model(**model_inputs)
#
# File ~/git_repos/dh2023/venv_sentiment-analysis/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/git_repos/dh2023/venv_sentiment-analysis/lib/python3.10/site-packages/transformers/models/distilbert/modeling_distilbert.py:763, in DistilBertForSequenceClassification.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     755 r"""
#     756 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#     757     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#     758     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#     759     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#     760 """
#     761 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 763 distilbert_output = self.distilbert(
#     764     input_ids=input_ids,
#     765     attention_mask=attention_mask,
#     766     head_mask=head_mask,
#     767     inputs_embeds=inputs_embeds,
#     768     output_attentions=output_attentions,
#     769     output_hidden_states=output_hidden_states,
#     770     return_dict=return_dict,
#     771 )
#     772 hidden_state = distilbert_output[0]  # (bs, seq_len, dim)
#     773 pooled_output = hidden_state[:, 0]  # (bs, dim)
#
# File ~/git_repos/dh2023/venv_sentiment-analysis/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/git_repos/dh2023/venv_sentiment-analysis/lib/python3.10/site-packages/transformers/models/distilbert/modeling_distilbert.py:583, in DistilBertModel.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     579 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     581 embeddings = self.embeddings(input_ids, inputs_embeds)  # (bs, seq_length, dim)
# --> 583 return self.transformer(
#     584     x=embeddings,
#     585     attn_mask=attention_mask,
#     586     head_mask=head_mask,
#     587     output_attentions=output_attentions,
#     588     output_hidden_states=output_hidden_states,
#     589     return_dict=return_dict,
#     590 )
#
# File ~/git_repos/dh2023/venv_sentiment-analysis/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/git_repos/dh2023/venv_sentiment-analysis/lib/python3.10/site-packages/transformers/models/distilbert/modeling_distilbert.py:359, in Transformer.forward(self, x, attn_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     356 if output_hidden_states:
#     357     all_hidden_states = all_hidden_states + (hidden_state,)
# --> 359 layer_outputs = layer_module(
#     360     x=hidden_state, attn_mask=attn_mask, head_mask=head_mask[i], output_attentions=output_attentions
#     361 )
#     362 hidden_state = layer_outputs[-1]
#     364 if output_attentions:
#
# File ~/git_repos/dh2023/venv_sentiment-analysis/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/git_repos/dh2023/venv_sentiment-analysis/lib/python3.10/site-packages/transformers/models/distilbert/modeling_distilbert.py:295, in TransformerBlock.forward(self, x, attn_mask, head_mask, output_attentions)
#     285 """
#     286 Parameters:
#     287     x: torch.tensor(bs, seq_length, dim)
#    (...)
#     292     torch.tensor(bs, seq_length, dim) The output of the transformer block contextualization.
#     293 """
#     294 # Self-Attention
# --> 295 sa_output = self.attention(
#     296     query=x,
#     297     key=x,
#     298     value=x,
#     299     mask=attn_mask,
#     300     head_mask=head_mask,
#     301     output_attentions=output_attentions,
#     302 )
#     303 if output_attentions:
#     304     sa_output, sa_weights = sa_output  # (bs, seq_length, dim), (bs, n_heads, seq_length, seq_length)
#
# File ~/git_repos/dh2023/venv_sentiment-analysis/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/git_repos/dh2023/venv_sentiment-analysis/lib/python3.10/site-packages/transformers/models/distilbert/modeling_distilbert.py:222, in MultiHeadSelfAttention.forward(self, query, key, value, mask, head_mask, output_attentions)
#     220 scores = torch.matmul(q, k.transpose(2, 3))  # (bs, n_heads, q_length, k_length)
#     221 mask = (mask == 0).view(mask_reshp).expand_as(scores)  # (bs, n_heads, q_length, k_length)
# --> 222 scores = scores.masked_fill(
#     223     mask, torch.tensor(torch.finfo(scores.dtype).min)
#     224 )  # (bs, n_heads, q_length, k_length)
#     226 weights = nn.functional.softmax(scores, dim=-1)  # (bs, n_heads, q_length, k_length)
#     227 weights = self.dropout(weights)  # (bs, n_heads, q_length, k_length)
#
# KeyboardInterrupt:
